# %% [markdown]
# # Data Wrangling

# %% [markdown]
# # Step of data wranglisg
# 1. Data Cleaning
# 2. Data transforming
# 3. organizing
# 4. Analysis and Visulization

# %%
#libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plot

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()*100/len(df)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.drop(columns='deck',inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 14)

# %%
#missing value
df['age']=df.age.fillna(value=df['age'].mean())

# %%
#embarked is a categoriacal value and then change mode 0 zero means start 0
df['embarked']=df.embarked.fillna(value=df['embarked'].mode()[0])

# %%
df.isnull().sum()*100/len(df)
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %%
df['embark_town']=df.embark_town.fillna(value=df['embark_town'].mode()[0])

# %%
df.isnull().sum()*100/len(df)
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %% [markdown]
# # outlier removal

# %% [markdown]
# # visulization method

# %%
import seaborn as sns
sns.boxenplot(data=df,y='age',hue='sex')
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# # IQR METHOD

# %%
Q1=df['age'].quantile(0.25)
Q3=df['age'].quantile(0.75)
IQR=Q3-Q1
IQR
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df=df[(df['age']>lower_bound)&(df['age']<upper_bound)]

# %%
Q1=df['fare'].quantile(0.25)
Q3=df['fare'].quantile(0.75)
IQR=Q3-Q1
IQR
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df=df[(df['fare']>lower_bound)&(df['fare']<upper_bound)]

# %%
df.shape
# Out:
# (718, 14)

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# # zee score

# %%
from scipy import stats
df['age'] = stats.zscore(df['age'])

threshold = 2

df = df[np.abs(df['age']) <= threshold]

# %%
df.shape
# Out:
# (718, 14)

# %% [markdown]
# # finding and droping duplicate

# %%
df.shape
# Out:
# (663, 14)

# %%
#find duplicate
df.duplicated().sum()
# Out:
# 0

# %%
df1=df[df.duplicated()]
df1.head()
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
#drop Duplicate
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (561, 14)

# %% [markdown]
# # transforming /Data Normalization

# %%
#1 pip install skikit-learn
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

#2 data 
df

#3 select colom to normolize
cols_to_normalize=['age','fare']

#4 create the scaller funcation or tool
scaler=MinMaxScaler()

#5 fit and transform the data on scaller vice versa
df[cols_to_normalize]=scaler.fit_transform(df[cols_to_normalize])

#6 check the data
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  0.333333      1      0  0.118512        S
# 2           1       3  female  0.435897      0      0  0.129546        S
# 3           1       1  female  0.666667      1      0  0.868002        S
# 4           0       3    male  0.666667      0      0  0.131590        S
# 5           0       3    male  0.530747      0      0  0.138264        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  0.769231      0      5  0.476093        Q
# 887         1       1  female  0.256410      0      0  0.490396        S
# 888         0       3  female  0.530747      1      2  0.383327        S
# 889         1       1    male  0.435897      0      0  0.490396        C
# 890         0       3    male  0.589744      0      0  0.126686        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
#minmax 0 to 1
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  561.000000  561.000000  561.000000  561.000000  561.000000  561.000000
# mean     0.344029    2.490196    0.501473    0.395722    0.324421    0.287860
# std      0.475474    0.737026    0.218758    0.792994    0.826952    0.217598
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.333333    0.000000    0.000000    0.128798
# 50%      0.000000    3.000000    0.530747    0.000000    0.000000    0.206784
# 75%      1.000000    3.000000    0.615385    1.000000    0.000000    0.425010
# max      1.000000    3.000000    1.000000    5.000000    6.000000    1.000000

# %%
#1 pip install skikit-learn
import pandas as pd
from sklearn.preprocessing import StandardScaler

#2 data 
df

#3 select colom to normolize
cols_to_normalize=['age','fare']

#4 create the scaller funcation or tool
scaler=StandardScaler()

#5 fit and transform the data on scaller vice versa
df[cols_to_normalize]=scaler.fit_transform(df[cols_to_normalize])

#6 check the data
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male -0.769294      1      0 -0.778951        S
# 2           1       3  female -0.300028      0      0 -0.728198        S
# 3           1       1  female  0.755819      1      0  2.668491        S
# 4           0       3    male  0.755819      0      0 -0.718799        S
# 5           0       3    male  0.133939      0      0 -0.688099        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  1.225085      0      5  0.865821        Q
# 887         1       1  female -1.121243      0      0  0.931612        S
# 888         0       3  female  0.133939      1      2  0.439120        S
# 889         1       1    male -0.300028      0      0  0.931612        C
# 890         0       3    male  0.403870      0      0 -0.741356        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass           age       sibsp       parch  \
# count  561.000000  561.000000  5.610000e+02  561.000000  561.000000
# mean     0.344029    2.490196 -3.799694e-16    0.395722    0.324421
# std      0.475474    0.737026  1.000892e+00    0.792994    0.826952
# min      0.000000    1.000000 -2.294407e+00    0.000000    0.000000
# 25%      0.000000    2.000000 -7.692938e-01    0.000000    0.000000
# 50%      0.000000    3.000000  1.339389e-01    0.000000    0.000000
# 75%      1.000000    3.000000  5.211865e-01    1.000000    0.000000
# max      1.000000    3.000000  2.280932e+00    5.000000    6.000000
#
#                fare
# count  5.610000e+02
# mean   6.332823e-18
# std    1.000892e+00
# min   -1.324075e+00
# 25%   -7.316415e-01
# 50%   -3.729271e-01
# 75%    6.308535e-01
# max    3.275646e+00

# %%
df.to_csv("preprocessor_data.csv")
